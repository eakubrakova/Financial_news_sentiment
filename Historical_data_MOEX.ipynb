# %%
# !pip install moexalgo
import pandas as pd
from moexalgo import Market

stocks = Market("shares/TQBR")
all_stocks = stocks.tickers()
all_stocks
# Out:
# Collecting moexalgo
#   Downloading moexalgo-1.0.1-py3-none-any.whl (21 kB)
# Collecting httpx (from moexalgo)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->moexalgo) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->moexalgo) (2024.2.2)
# Collecting httpcore==1.* (from httpx->moexalgo)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->moexalgo) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->moexalgo) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->moexalgo)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->moexalgo) (1.2.0)
# Installing collected packages: h11, httpcore, httpx, moexalgo
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 moexalgo-1.0.1
#     ticker   shortname  lotsize  decimals  minstep   issuesize          isin  \
# 0     ABIO  iАРТГЕН ао       10         2    0.020    92645451  RU000A0JNAB6
# 1     ABRD  АбрауДюрсо       10         1    0.200    98000184  RU000A0JS5T7
# 2     ACKO     АСКО ао      100         2    0.020   536000000  RU000A0JXS91
# 3     AFKS  Система ао      100         3    0.001  9650000000  RU000A0DQZE3
# 4     AFLT    Аэрофлот       10         2    0.010  3975771215  RU0009062285
# ..     ...         ...      ...       ...      ...         ...           ...
# 241   YNDX  Yandex clA        1         1    0.200   326342270  NL0009805522
# 242   YRSB     ТНСэнЯр       10         0    2.000    17143584  RU000A0D8760
# 243  YRSBP   ТНСэнЯр-п       10         1    0.500     4507320  RU000A0D88B3
# 244   ZILL      ЗИЛ ао        1         0    5.000     2659962  RU0009086193
# 245   ZVEZ   ЗВЕЗДА ао     1000         2    0.010   562020480  RU0009091300
#
#         regnumber  listlevel
# 0    1-01-08902-A          2
# 1    1-02-12500-A          3
# 2    1-01-52065-Z          3
# 3    1-05-01669-A          1
# 4    1-01-00010-A          1
# ..            ...        ...
# 241          None          1
# 242  1-01-50099-A          3
# 243  2-01-50099-A          3
# 244  1-02-00036-A          3
# 245  1-01-00169-D          3
#
# [246 rows x 9 columns]

# %%
all_stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ticker     246 non-null    object
#  1   shortname  246 non-null    object
#  2   lotsize    246 non-null    int64
#  3   decimals   246 non-null    int64
#  4   minstep    246 non-null    float64
#  5   issuesize  246 non-null    int64
#  6   isin       246 non-null    object
#  7   regnumber  246 non-null    object
#  8   listlevel  246 non-null    int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 17.4+ KB

# %%
import pandas as pd
from moexalgo import Market

stocks = Market("stocks")
all_stocks = pd.DataFrame(stocks.tickers())
print(all_stocks.columns.tolist())
listlevels = sorted(all_stocks["listlevel"].unique())
with open("list_tools_level", "w", encoding="utf-8") as file:
    print(f"Всего в Алгопаке доступны данные по {all_stocks.shape[0]} акциям Мосбиржи")
    print(
        f"Всего в Алгопаке доступны данные по {all_stocks.shape[0]} акциям Мосбиржи",
        file=file,
    )
    for level in listlevels:
        stocks_level = all_stocks[all_stocks["listlevel"] == level]
        print(f"Для {level} уровня листинга отобрано {stocks_level.shape[0]} акций:")
        print(
            f"Для {level} уровня листинга отобрано {stocks_level.shape[0]} акций:",
            file=file,
        )
        list_tickers = stocks_level["ticker"].tolist()
        list_shortnames = stocks_level["shortname"].tolist()
        for ticker, shortname in zip(list_tickers, list_shortnames):
            print(f"{ticker} - {shortname}")
            print(f"{ticker} - {shortname}", file=file)
        print("_" * 70)
        print("_" * 70, file=file)
# Out:
# ['ticker', 'shortname', 'lotsize', 'decimals', 'minstep', 'issuesize', 'isin', 'regnumber', 'listlevel']
# Всего в Алгопаке доступны данные по 246 акциям Мосбиржи
# Для 1 уровня листинга отобрано 67 акций:
# AFKS - Система ао
# AFLT - Аэрофлот
# AGRO - AGRO-гдр
# ALRS - АЛРОСА ао
# AQUA - ИНАРКТИКА
# BELU - НоваБев ао
# BSPB - БСП ао
# CBOM - МКБ ао
# CHMF - СевСт-ао
# CIAN - CIAN-адр
# ELFV - ЭЛ5Энер ао
# ENPG - ЭН+ГРУП ао
# ETLN - ETLN-гдр
# EUTR - ЕвроТранс
# FEES - Россети
# FIVE - FIVE-гдр
# FIXP - FIXP-гдр
# FLOT - Совкомфлот
# GAZP - ГАЗПРОМ ао
# GEMC - МКПАО ЮМГ
# GLTR - GLTR-гдр
# GMKN - ГМКНорНик
# HHRU - iHHRU-адр
# HYDR - РусГидро
# IRAO - ИнтерРАОао
# LEAS - Европлан
# LENT - Лента ао
# LKOH - ЛУКОЙЛ
# LSRG - ЛСР ао
# MAGN - ММК
# MDMG - MDMG-гдр
# MOEX - МосБиржа
# MSNG - +МосЭнерго
# MTLR - Мечел ао
# MTLRP - Мечел ап
# MTSS - МТС-ао
# MVID - М.видео
# NLMK - НЛМК ао
# NVTK - Новатэк ао
# OKEY - OKEY-гдр
# OZON - OZON-адр
# PHOR - ФосАгро ао
# PIKK - ПИК ао
# PLZL - Полюс
# POSI - iПозитив
# RENI - Ренессанс
# RNFT - РуссНфт ао
# ROSN - Роснефть
# RTKM - Ростел -ао
# RTKMP - Ростел -ап
# RUAL - РУСАЛ ао
# SBER - Сбербанк
# SBERP - Сбербанк-п
# SELG - Селигдар
# SFIN - ЭсЭфАй ао
# SGZH - Сегежа
# SMLT - Самолет ао
# SVCB - Совкомбанк
# TATN - Татнфт 3ао
# TATNP - Татнфт 3ап
# TCSG - ТКСХолд ао
# TGKA - ТГК-1
# TRNFP - Транснф ап
# UPRO - Юнипро ао
# VKCO - МКПАО "ВК"
# VTBR - ВТБ ао
# YNDX - Yandex clA
# ______________________________________________________________________
# Для 2 уровня листинга отобрано 27 акций:
# ABIO - iАРТГЕН ао
# AKRN - Акрон
# APTK - Аптеки36и6
# ASTR - Астра ао
# DELI - Каршеринг
# DIAS - Диасофт
# FESH - ДВМП ао
# HNFG - ХЭНДЕРСОН
# KMAZ - КАМАЗ
# MRKC - РоссЦентр
# MRKP - РСетиЦП ао
# MRKS - РсетСиб ао
# MRKU - Россети Ур
# MRKV - РсетВол ао
# MRKZ - РСетиСЗ ао
# MSRS - РСетиМР ао
# OGKB - ОГК-2 ао
# RASP - Распадская
# SNGS - Сургнфгз
# SNGSP - Сургнфгз-п
# SOFL - iСофтлайн
# SVAV - СОЛЛЕРС
# TGKN - ТГК-14
# TRMK - ТМК ао
# UGLD - ЮГК
# VSMO - ВСМПО-АВСМ
# WUSH - iВУШХолднг
# ______________________________________________________________________
# Для 3 уровня листинга отобрано 152 акций:
# ABRD - АбрауДюрсо
# ACKO - АСКО ао
# AMEZ - АшинскийМЗ
# ARSA - Арсагера
# ASSB - АстрЭнСб
# AVAN - Авангрд-ао
# BANE - Башнефт ао
# BANEP - Башнефт ап
# BISVP - БашИнСв ап
# BLNG - Белон ао
# BRZL - БурЗолото
# BSPBP - БСП ап
# CARM - СТГ
# CHGZ - РН-ЗапСиб
# CHKZ - ЧКПЗ ао
# CHMK - ЧМК ао
# CNTL - Телеграф
# CNTLP - Телеграф-п
# DIOD - ЗаводДИОД
# DVEC - ДЭК ао
# DZRD - ДонскЗР
# DZRDP - ДонскЗР п
# EELT - ЕвроЭлтех
# GAZC - ГАЗКОН-ао
# GAZS - ГАЗ-сервис
# GAZT - ГАЗ-Тек ао
# GCHE - ЧеркизГ-ао
# GECO - iГЕНЕТИКО
# GEMA - iММЦБ ао
# GTRK - ГТМ ао
# HIMCP - Химпром ап
# IGST - Ижсталь2ао
# IGSTP - Ижсталь ап
# INGR - ИНГРАД ао
# IRKT - Яковлев-3
# JNOS - Славн-ЯНОС
# JNOSP - Слав-ЯНОСп
# KAZT - Куйбазот
# KAZTP - Куйбазот-п
# KBSB - ТНСэКубань
# KCHE - КамчатЭ ао
# KCHEP - КамчатЭ ап
# KGKC - КурганГКао
# KGKCP - КурганГКап
# KLSB - КалужскСК
# KLVZ - Кристалл
# KMEZ - КМЗ
# KOGK - КоршГОК ао
# KRKN - СаратНПЗ
# KRKNP - СаратНПЗ-п
# KRKOP - ТКЗКК ап
# KROT - КрасОкт-ао
# KROTP - КрасОкт-1п
# KRSB - Красэсб ао
# KRSBP - Красэсб ап
# KUBE - РСетКубань
# KUZB - КузнецкийБ
# KZOS - ОргСинт ао
# KZOSP - ОргСинт ап
# LNZL - Лензолото
# LNZLP - Лензол. ап
# LSNG - РСетиЛЭ
# LSNGP - РСетиЛЭ-п
# LVHK - Левенгук
# MAGE - МагадЭн ао
# MAGEP - МагадЭн ап
# MFGS - Мегион-ао
# MFGSP - Мегион-ап
# MGKL - МГКЛ
# MGNT - Магнит ао
# MGNZ - СМЗ-ао
# MGTS - МГТС-5ао
# MGTSP - МГТС-4ап
# MISB - ТНСэнМарЭл
# MISBP - ТНСэМаЭл-п
# MRKK - Россети СК
# MRKY - РоссЮг ао
# MRSB - МордЭнСб
# MSTT - Мостотрест
# NAUK - iНПОНаука
# NFAZ - НЕФАЗ
# NKHP - НКХП ао
# NKNC - НКНХ ао
# NKNCP - НКНХ ап
# NKSH - Нижкамшина
# NMTP - НМТП ао
# NNSB - ТНСэнНН ао
# NNSBP - ТНСэнНН ап
# NSVZ - iНаукаСвяз
# OMZZP - ОМЗ-ап
# PMSB - ПермьЭнСб
# PMSBP - ПермьЭнС-п
# POLY - Polymetal
# PRFN - ЧЗПСН ао
# PRMB - Приморье
# QIWI - iQIWI
# RBCM - ГК РБК ао
# RDRB - РДБанк ао
# RGSS - РГС СК ао
# RKKE - ЭнергияРКК
# ROLO - Русолово
# ROSB - Росбанк ао
# ROST - РОСИНТЕРао
# RTGZ - ГазпРнД ао
# RTSB - ТНСэнРст
# RTSBP - ТНСэнРст-п
# RUSI - ИКРУСС-ИНВ
# RZSB - РязЭнСб
# SAGO - СамарЭн-ао
# SAGOP - СамарЭн-ап
# SARE - СаратЭн-ао
# SAREP - СаратЭн-ап
# SIBN - Газпрнефть
# SLEN - Сахэнер ао
# SPBE - СПБ Биржа
# STSB - СтаврЭнСб
# STSBP - СтаврЭнСбп
# SVET - Светофор
# TASB - ТамбЭнСб
# TASBP - ТамбЭнСб-п
# TGKB - ТГК-2
# TGKBP - ТГК-2 ап
# TNSE - ТНСэнрг ао
# TORS - ТРК ао
# TORSP - ТРК ап
# TTLK - Таттел. ао
# TUZA - ТЗА ао
# UKUZ - ЮжКузб. ао
# UNAC - iАвиастКао
# UNKL - ЮУНК ао
# URKZ - УрКузница
# USBN - УралСиб ао
# UTAR - ЮТэйр ао
# VEON-RX - VEON
# VGSB - ВолгЭнСб
# VGSBP - ВолгЭнСб-п
# VJGZ - Варьеган
# VJGZP - Варьеган-п
# VLHZ - ВХЗ-ао
# VRSB - ТНСэнВорон
# VRSBP - ТНСэнВор-п
# VSYD - ВыбСудЗ ао
# VSYDP - ВыбСудЗ ап
# WTCM - ЦМТ ао
# WTCMP - ЦМТ ап
# YAKG - ЯТЭК ао
# YKEN - Якутскэнрг
# YKENP - Якутскэн-п
# YRSB - ТНСэнЯр
# YRSBP - ТНСэнЯр-п
# ZILL - ЗИЛ ао
# ZVEZ - ЗВЕЗДА ао
# ______________________________________________________________________

# %%
index =  Market("index/SNDX")
indices = index.tickers()  # Вызоваем метод tickers() на экземпляре класса Market
indices = pd.DataFrame(index.tickers())
indices.head(30)
# Out:
#          ticker  decimals                       shortname
# 0         IMOEX         2                 Индекс МосБиржи
# 1        IMOEX2         2    Индекс МосБиржи (все сессии)
# 2        MECHTR         4     MOEX Chemicals Total Return
# 3       MECHTRN         4        MOEX Chemicals Net TR-NR
# 4       MECHTRR         4       MOEX Chemicals Net TR-Res
# 5        MECNTR         4      MOEX Consumer Total Return
# 6       MECNTRN         4         MOEX Consumer Net TR-NR
# 7       MECNTRR         4        MOEX Consumer Net TR-Res
# 8        MEEUTR         4  MOEX El.Utilities Total Return
# 9       MEEUTRN         4    MOEX El. Utilities Net TR-NR
# 10      MEEUTRR         4   MOEX El. Utilities Net TR-Res
# 11       MEFNTR         4    MOEX Financials Total Return
# 12      MEFNTRN         4       MOEX Financials Net TR-NR
# 13      MEFNTRR         4      MOEX Financials Net TR-Res
# 14       MEMMTR         4  MOEX Metals & Min Total Return
# 15      MEMMTRN         4  MOEX Metals & Mining Net TR-NR
# 16      MEMMTRR         4    MOEX Metals & Min Net TR-Res
# 17       MEOGTR         4     MOEX Oil & Gas Total Return
# 18      MEOGTRN         4        MOEX Oil & Gas Net TR-NR
# 19      MEOGTRR         4       MOEX Oil & Gas Net TR-Res
# 20       MESMTR         4          MOEX SMID Total Return
# 21      MESMTRN         4             MOEX SMID Net TR-NR
# 22      MESMTRR         4            MOEX SMID Net TR-Res
# 23       METLTR         4       MOEX Telecom Total Return
# 24      METLTRN         4          MOEX Telecom Net TR-NR
# 25      METLTRR         4         MOEX Telecom Net TR-Res
# 26       METNTR         4     MOEX Transport Total Return
# 27      METNTRN         4        MOEX Transport Net TR-NR
# 28      METNTRR         4       MOEX Transport Net TR-Res
# 29  MICEXBORR1W         4                       MCX BO 1W
